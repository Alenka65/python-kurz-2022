# %%
import pandas
platy = pandas.read_csv("platy_2021_03.csv")
platy.head()
# Out:
#    cislo_zamestnance     plat
# 0                  3  54900.0
# 1                  6  54800.0
# 2                  7  36400.0
# 3                  8  47900.0
# 4                 16  34200.0

# %% [markdown]
# Histogram

# %%
platy['plat'].plot(kind='hist', bins=6, grid=True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
platy['plat'].plot(kind='hist', bins=[30000, 35000, 40000, 45000, 50000, 55000, 60000], grid=True)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Zkusila jsem pridat vic hodnot do bins

# %%
platy['plat'].plot(kind='hist', bins=[30000, 32000, 35000, 37000, 40000, 42000, 45000, 47000, 50000, 52000, 55000, 57000,60000], grid=True)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Krabicovy

# %%
platy['plat'].plot(kind='box', whis=[0,50])
# Out:
# <Axes: >
